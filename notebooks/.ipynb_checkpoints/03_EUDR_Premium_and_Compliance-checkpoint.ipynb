# %%
import pandas as pd
import numpy as np

# Load the re-scaled Market 
df = pd.read_csv('../data/processed/romina_market_linked_v2.csv')

EUDR_PREMIUM_UPLIFT = 1.22  
GERMANY_FIXED_QUALITY_PREMIUM = 0.50 

print("EUDR Strategy Engine Online.")
# Out:
# EUDR Strategy Engine Online.
